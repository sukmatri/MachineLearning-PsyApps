# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('survey.csv')

# %%
dataset
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# 0                No       Yes          Often            6-25  ...
# 1                No        No         Rarely  More than 1000  ...
# 2                No        No         Rarely            6-25  ...
# 3               Yes       Yes          Often          26-100  ...
# 4                No        No          Never         100-500  ...
# ...             ...       ...            ...             ...  ...
# 1254             No       Yes            NaN          26-100  ...
# 1255            Yes       Yes          Often          26-100  ...
# 1256            Yes       Yes      Sometimes  More than 1000  ...
# 1257             No        No            NaN         100-500  ...
# 1258            Yes       Yes      Sometimes          26-100  ...
#
#                    leave mental_health_consequence phys_health_consequence  \
# 0          Somewhat easy                        No                      No
# 1             Don't know                     Maybe                      No
# 2     Somewhat difficult                        No                      No
# 3     Somewhat difficult                       Yes                     Yes
# 4             Don't know                        No                      No
# ...                  ...                       ...                     ...
# 1254       Somewhat easy                        No                      No
# 1255  Somewhat difficult                        No                      No
# 1256  Somewhat difficult                       Yes                     Yes
# 1257          Don't know                       Yes                      No
# 1258          Don't know                     Maybe                      No
#
#          coworkers    supervisor mental_health_interview  \
# 0     Some of them           Yes                      No
# 1               No            No                      No
# 2              Yes           Yes                     Yes
# 3     Some of them            No                   Maybe
# 4     Some of them           Yes                     Yes
# ...            ...           ...                     ...
# 1254  Some of them  Some of them                      No
# 1255  Some of them           Yes                      No
# 1256            No            No                      No
# 1257            No            No                      No
# 1258  Some of them            No                      No
#
#      phys_health_interview mental_vs_physical obs_consequence comments
# 0                    Maybe                Yes              No      NaN
# 1                       No         Don't know              No      NaN
# 2                      Yes                 No              No      NaN
# 3                    Maybe                 No             Yes      NaN
# 4                      Yes         Don't know              No      NaN
# ...                    ...                ...             ...      ...
# 1254                    No         Don't know              No      NaN
# 1255                    No                Yes              No      NaN
# 1256                    No                 No              No      NaN
# 1257                    No                 No              No      NaN
# 1258                    No         Don't know              No      NaN
#
# [1259 rows x 27 columns]

# %%
dataset = dataset.drop(['Timestamp', 'Country', 'state', 'self_employed', 'leave', 'comments', 'obs_consequence', 'anonymity', 'no_employees', 'remote_work', 'tech_company', 'benefits', 'coworkers', 'supervisor', 'mental_health_interview', 'phys_health_interview', 'mental_vs_physical'], axis = 1)

# %%
dataset
# Out:
#       Age  Gender family_history treatment work_interfere care_options  \
# 0      37  Female             No       Yes          Often     Not sure
# 1      44       M             No        No         Rarely           No
# 2      32    Male             No        No         Rarely           No
# 3      31    Male            Yes       Yes          Often          Yes
# 4      31    Male             No        No          Never           No
# ...   ...     ...            ...       ...            ...          ...
# 1254   26    male             No       Yes            NaN           No
# 1255   32    Male            Yes       Yes          Often          Yes
# 1256   34    male            Yes       Yes      Sometimes          Yes
# 1257   46       f             No        No            NaN          Yes
# 1258   25    Male            Yes       Yes      Sometimes          Yes
#
#      wellness_program   seek_help mental_health_consequence  \
# 0                  No         Yes                        No
# 1          Don't know  Don't know                     Maybe
# 2                  No          No                        No
# 3                  No          No                       Yes
# 4          Don't know  Don't know                        No
# ...               ...         ...                       ...
# 1254               No          No                        No
# 1255               No          No                        No
# 1256               No          No                       Yes
# 1257               No          No                       Yes
# 1258               No          No                     Maybe
#
#      phys_health_consequence
# 0                         No
# 1                         No
# 2                         No
# 3                        Yes
# 4                         No
# ...                      ...
# 1254                      No
# 1255                      No
# 1256                     Yes
# 1257                      No
# 1258                      No
#
# [1259 rows x 10 columns]

# %%
dataset.isna().sum()
# Out:
# Age                            0
# Gender                         0
# family_history                 0
# treatment                      0
# work_interfere               264
# care_options                   0
# wellness_program               0
# seek_help                      0
# mental_health_consequence      0
# phys_health_consequence        0
# dtype: int64

# %%
dataset[dataset.work_interfere.isna()]
# Out:
#       Age  Gender family_history treatment work_interfere care_options  \
# 19     36    Male            Yes        No            NaN           No
# 26     33    male             No        No            NaN     Not sure
# 37     38    Male             No        No            NaN          Yes
# 38     50       M             No        No            NaN          Yes
# 41     35    Male             No        No            NaN     Not sure
# ...   ...     ...            ...       ...            ...          ...
# 1226   39    Male             No        No            NaN     Not sure
# 1229   39    Male             No        No            NaN           No
# 1244   32  female             No        No            NaN           No
# 1254   26    male             No       Yes            NaN           No
# 1257   46       f             No        No            NaN          Yes
#
#      wellness_program   seek_help mental_health_consequence  \
# 19                Yes          No                        No
# 26                 No  Don't know                     Maybe
# 37                 No          No                     Maybe
# 38                 No  Don't know                        No
# 41         Don't know         Yes                       Yes
# ...               ...         ...                       ...
# 1226              Yes  Don't know                     Maybe
# 1229               No          No                       Yes
# 1244               No  Don't know                     Maybe
# 1254               No          No                        No
# 1257               No          No                       Yes
#
#      phys_health_consequence
# 19                        No
# 26                     Maybe
# 37                        No
# 38                        No
# 41                       Yes
# ...                      ...
# 1226                   Maybe
# 1229                      No
# 1244                      No
# 1254                      No
# 1257                      No
#
# [264 rows x 10 columns]

# %%
dataset.work_interfere.fillna(value = "Adaptive", inplace = True)

# %%
dataset.duplicated().sum()
# Out:
# 46

# %%
dataset.drop_duplicates(inplace = True)

# %%
dataset
# Out:
#       Age  Gender family_history treatment work_interfere care_options  \
# 0      37  Female             No       Yes          Often     Not sure
# 1      44       M             No        No         Rarely           No
# 2      32    Male             No        No         Rarely           No
# 3      31    Male            Yes       Yes          Often          Yes
# 4      31    Male             No        No          Never           No
# ...   ...     ...            ...       ...            ...          ...
# 1254   26    male             No       Yes       Adaptive           No
# 1255   32    Male            Yes       Yes          Often          Yes
# 1256   34    male            Yes       Yes      Sometimes          Yes
# 1257   46       f             No        No       Adaptive          Yes
# 1258   25    Male            Yes       Yes      Sometimes          Yes
#
#      wellness_program   seek_help mental_health_consequence  \
# 0                  No         Yes                        No
# 1          Don't know  Don't know                     Maybe
# 2                  No          No                        No
# 3                  No          No                       Yes
# 4          Don't know  Don't know                        No
# ...               ...         ...                       ...
# 1254               No          No                        No
# 1255               No          No                        No
# 1256               No          No                       Yes
# 1257               No          No                       Yes
# 1258               No          No                     Maybe
#
#      phys_health_consequence
# 0                         No
# 1                         No
# 2                         No
# 3                        Yes
# 4                         No
# ...                      ...
# 1254                      No
# 1255                      No
# 1256                     Yes
# 1257                      No
# 1258                      No
#
# [1213 rows x 10 columns]

# %%
dataset.Gender.value_counts()
# Out:
# Gender
# Male                                              579
# male                                              200
# Female                                            121
# M                                                 112
# female                                             62
# F                                                  38
# m                                                  34
# f                                                  15
# Make                                                4
# Male                                                3
# Woman                                               3
# Cis Male                                            2
# Man                                                 2
# Female (trans)                                      2
# Female                                              2
# Trans woman                                         1
# msle                                                1
# male leaning androgynous                            1
# Neuter                                              1
# cis male                                            1
# queer                                               1
# Female (cis)                                        1
# Mail                                                1
# cis-female/femme                                    1
# A little about you                                  1
# Malr                                                1
# p                                                   1
# femail                                              1
# Cis Man                                             1
# Guy (-ish) ^_^                                      1
# Enby                                                1
# Agender                                             1
# Androgyne                                           1
# Male-ish                                            1
# maile                                               1
# Trans-female                                        1
# Cis Female                                          1
# something kinda male?                               1
# Mal                                                 1
# Male (CIS)                                          1
# queer/she/they                                      1
# non-binary                                          1
# Femake                                              1
# woman                                               1
# Nah                                                 1
# All                                                 1
# fluid                                               1
# Genderqueer                                         1
# ostensibly male, unsure what that really means      1
# Name: count, dtype: int64

# %%
dataset['Gender'].replace(['Male ', 'male', 'M', 'm', 'Male', 'Cis Male','Man', 'cis male', 'Mail', 'Male-ish', 'Male (CIS)',
                    'Cis Man', 'msle', 'Malr', 'Mal', 'maile', 'Make',], 'Male', inplace = True)

dataset['Gender'].replace(['Female ', 'female', 'F', 'f', 'Woman', 'Female','femail', 'Cis Female', 'cis-female/femme',
                    'Femake', 'Female (cis)','woman',], 'Female', inplace = True)

dataset["Gender"].replace(['Female (trans)', 'queer/she/they', 'non-binary','fluid', 'queer', 'Androgyne', 'Trans-female', 'male leaning androgynous',
                      'Agender', 'A little about you', 'Nah', 'All','ostensibly male, unsure what that really means',
                      'Genderqueer', 'Enby', 'p', 'Neuter', 'something kinda male?','Guy (-ish) ^_^', 'Trans woman',], 'Others', inplace = True)

# %%
dataset.Gender.value_counts()
# Out:
# Gender
# Male      945
# Female    247
# Others     21
# Name: count, dtype: int64

# %%
dataset.Age.value_counts()
# Out:
# Age
#  29             80
#  32             78
#  26             73
#  33             68
#  34             65
#  27             65
#  31             64
#  28             63
#  30             60
#  25             57
#  35             51
#  23             49
#  24             46
#  37             41
#  38             39
#  36             35
#  39             33
#  40             32
#  43             28
#  41             21
#  22             21
#  42             20
#  21             16
#  45             12
#  46             12
#  44             11
#  19              9
#  18              7
#  48              6
#  20              6
#  50              5
#  51              5
#  49              4
#  56              4
#  57              3
#  54              3
#  55              3
#  47              2
#  60              2
#  99999999999     1
#  5               1
# -1               1
#  11              1
#  8               1
#  61              1
#  53              1
# -29              1
# -1726            1
#  65              1
#  62              1
#  58              1
#  329             1
#  72              1
# Name: count, dtype: int64

# %%
dataset['Age'].replace([dataset['Age'][dataset['Age'] < 18]], 18, inplace = True)
dataset['Age'].replace([dataset['Age'][dataset['Age'] > 72]], 72, inplace = True)

# %%
dataset.Age.value_counts()
# Out:
# Age
# 29    80
# 32    78
# 26    73
# 33    68
# 34    65
# 27    65
# 31    64
# 28    63
# 30    60
# 25    57
# 35    51
# 23    49
# 24    46
# 37    41
# 38    39
# 36    35
# 39    33
# 40    32
# 43    28
# 41    21
# 22    21
# 42    20
# 21    16
# 18    13
# 45    12
# 46    12
# 44    11
# 19     9
# 48     6
# 20     6
# 50     5
# 51     5
# 49     4
# 56     4
# 55     3
# 72     3
# 57     3
# 54     3
# 47     2
# 60     2
# 58     1
# 62     1
# 65     1
# 53     1
# 61     1
# Name: count, dtype: int64

# %%
dataset.isna().sum()
# Out:
# Age                          0
# Gender                       0
# family_history               0
# treatment                    0
# work_interfere               0
# care_options                 0
# wellness_program             0
# seek_help                    0
# mental_health_consequence    0
# phys_health_consequence      0
# dtype: int64

# %%
dataset.Age.describe()
# Out:
# count    1213.000000
# mean       32.136851
# std         7.574236
# min        18.000000
# 25%        27.000000
# 50%        31.000000
# 75%        36.000000
# max        72.000000
# Name: Age, dtype: float64

# %%
dataset
# Out:
#       Age  Gender family_history treatment work_interfere care_options  \
# 0      37  Female             No       Yes          Often     Not sure
# 1      44    Male             No        No         Rarely           No
# 2      32    Male             No        No         Rarely           No
# 3      31    Male            Yes       Yes          Often          Yes
# 4      31    Male             No        No          Never           No
# ...   ...     ...            ...       ...            ...          ...
# 1254   26    Male             No       Yes       Adaptive           No
# 1255   32    Male            Yes       Yes          Often          Yes
# 1256   34    Male            Yes       Yes      Sometimes          Yes
# 1257   46  Female             No        No       Adaptive          Yes
# 1258   25    Male            Yes       Yes      Sometimes          Yes
#
#      wellness_program   seek_help mental_health_consequence  \
# 0                  No         Yes                        No
# 1          Don't know  Don't know                     Maybe
# 2                  No          No                        No
# 3                  No          No                       Yes
# 4          Don't know  Don't know                        No
# ...               ...         ...                       ...
# 1254               No          No                        No
# 1255               No          No                        No
# 1256               No          No                       Yes
# 1257               No          No                       Yes
# 1258               No          No                     Maybe
#
#      phys_health_consequence
# 0                         No
# 1                         No
# 2                         No
# 3                        Yes
# 4                         No
# ...                      ...
# 1254                      No
# 1255                      No
# 1256                     Yes
# 1257                      No
# 1258                      No
#
# [1213 rows x 10 columns]

# %%
dataset.family_history.value_counts()
# Out:
# family_history
# No     733
# Yes    480
# Name: count, dtype: int64

# %%
dataset.treatment.value_counts()
# Out:
# treatment
# Yes    624
# No     589
# Name: count, dtype: int64

# %%
dataset.work_interfere.value_counts()
# Out:
# work_interfere
# Sometimes    456
# Adaptive     244
# Never        206
# Rarely       167
# Often        140
# Name: count, dtype: int64

# %%
dataset.care_options.value_counts()
# Out:
# care_options
# No          474
# Yes         435
# Not sure    304
# Name: count, dtype: int64

# %%
dataset.wellness_program.value_counts()
# Out:
# wellness_program
# No            806
# Yes           224
# Don't know    183
# Name: count, dtype: int64

# %%
dataset.seek_help.value_counts()
# Out:
# seek_help
# No            614
# Don't know    355
# Yes           244
# Name: count, dtype: int64

# %%
dataset.mental_health_consequence.value_counts()
# Out:
# mental_health_consequence
# Maybe    464
# No       461
# Yes      288
# Name: count, dtype: int64

# %%
dataset.phys_health_consequence.value_counts()
# Out:
# phys_health_consequence
# No       888
# Maybe    264
# Yes       61
# Name: count, dtype: int64

# %%
dataset
# Out:
#       Age  Gender family_history treatment work_interfere care_options  \
# 0      37  Female             No       Yes          Often     Not sure
# 1      44    Male             No        No         Rarely           No
# 2      32    Male             No        No         Rarely           No
# 3      31    Male            Yes       Yes          Often          Yes
# 4      31    Male             No        No          Never           No
# ...   ...     ...            ...       ...            ...          ...
# 1254   26    Male             No       Yes       Adaptive           No
# 1255   32    Male            Yes       Yes          Often          Yes
# 1256   34    Male            Yes       Yes      Sometimes          Yes
# 1257   46  Female             No        No       Adaptive          Yes
# 1258   25    Male            Yes       Yes      Sometimes          Yes
#
#      wellness_program   seek_help mental_health_consequence  \
# 0                  No         Yes                        No
# 1          Don't know  Don't know                     Maybe
# 2                  No          No                        No
# 3                  No          No                       Yes
# 4          Don't know  Don't know                        No
# ...               ...         ...                       ...
# 1254               No          No                        No
# 1255               No          No                        No
# 1256               No          No                       Yes
# 1257               No          No                       Yes
# 1258               No          No                     Maybe
#
#      phys_health_consequence
# 0                         No
# 1                         No
# 2                         No
# 3                        Yes
# 4                         No
# ...                      ...
# 1254                      No
# 1255                      No
# 1256                     Yes
# 1257                      No
# 1258                      No
#
# [1213 rows x 10 columns]

# %%
dataset.Age.value_counts()
# Out:
# Age
# 29    80
# 32    78
# 26    73
# 33    68
# 34    65
# 27    65
# 31    64
# 28    63
# 30    60
# 25    57
# 35    51
# 23    49
# 24    46
# 37    41
# 38    39
# 36    35
# 39    33
# 40    32
# 43    28
# 41    21
# 22    21
# 42    20
# 21    16
# 18    13
# 45    12
# 46    12
# 44    11
# 19     9
# 48     6
# 20     6
# 50     5
# 51     5
# 49     4
# 56     4
# 55     3
# 72     3
# 57     3
# 54     3
# 47     2
# 60     2
# 58     1
# 62     1
# 65     1
# 53     1
# 61     1
# Name: count, dtype: int64

# %%
dataset.Gender.value_counts()
# Out:
# Gender
# Male      945
# Female    247
# Others     21
# Name: count, dtype: int64

# %%
Gender_map = {'Male': 0, 'Female': 1, 'Others': 2}
dataset['Gender'] = dataset['Gender'].map(Gender_map)

# %%
dataset
# Out:
#       Age  Gender family_history treatment work_interfere care_options  \
# 0      37       1             No       Yes          Often     Not sure
# 1      44       0             No        No         Rarely           No
# 2      32       0             No        No         Rarely           No
# 3      31       0            Yes       Yes          Often          Yes
# 4      31       0             No        No          Never           No
# ...   ...     ...            ...       ...            ...          ...
# 1254   26       0             No       Yes       Adaptive           No
# 1255   32       0            Yes       Yes          Often          Yes
# 1256   34       0            Yes       Yes      Sometimes          Yes
# 1257   46       1             No        No       Adaptive          Yes
# 1258   25       0            Yes       Yes      Sometimes          Yes
#
#      wellness_program   seek_help mental_health_consequence  \
# 0                  No         Yes                        No
# 1          Don't know  Don't know                     Maybe
# 2                  No          No                        No
# 3                  No          No                       Yes
# 4          Don't know  Don't know                        No
# ...               ...         ...                       ...
# 1254               No          No                        No
# 1255               No          No                        No
# 1256               No          No                       Yes
# 1257               No          No                       Yes
# 1258               No          No                     Maybe
#
#      phys_health_consequence
# 0                         No
# 1                         No
# 2                         No
# 3                        Yes
# 4                         No
# ...                      ...
# 1254                      No
# 1255                      No
# 1256                     Yes
# 1257                      No
# 1258                      No
#
# [1213 rows x 10 columns]

# %%
dataset.family_history.value_counts()
# Out:
# family_history
# No     733
# Yes    480
# Name: count, dtype: int64

# %%
family_map = {'No': 0, 'Yes': 1}
dataset['family_history'] = dataset['family_history'].map(family_map)

# %%
dataset
# Out:
#       Age  Gender  family_history treatment work_interfere care_options  \
# 0      37       1               0       Yes          Often     Not sure
# 1      44       0               0        No         Rarely           No
# 2      32       0               0        No         Rarely           No
# 3      31       0               1       Yes          Often          Yes
# 4      31       0               0        No          Never           No
# ...   ...     ...             ...       ...            ...          ...
# 1254   26       0               0       Yes       Adaptive           No
# 1255   32       0               1       Yes          Often          Yes
# 1256   34       0               1       Yes      Sometimes          Yes
# 1257   46       1               0        No       Adaptive          Yes
# 1258   25       0               1       Yes      Sometimes          Yes
#
#      wellness_program   seek_help mental_health_consequence  \
# 0                  No         Yes                        No
# 1          Don't know  Don't know                     Maybe
# 2                  No          No                        No
# 3                  No          No                       Yes
# 4          Don't know  Don't know                        No
# ...               ...         ...                       ...
# 1254               No          No                        No
# 1255               No          No                        No
# 1256               No          No                       Yes
# 1257               No          No                       Yes
# 1258               No          No                     Maybe
#
#      phys_health_consequence
# 0                         No
# 1                         No
# 2                         No
# 3                        Yes
# 4                         No
# ...                      ...
# 1254                      No
# 1255                      No
# 1256                     Yes
# 1257                      No
# 1258                      No
#
# [1213 rows x 10 columns]

# %%
dataset.treatment.value_counts()
# Out:
# treatment
# Yes    624
# No     589
# Name: count, dtype: int64

# %%
treatment_map = {'No': 0, 'Yes': 1}
dataset['treatment'] = dataset['treatment'].map(treatment_map)

# %%
dataset
# Out:
#       Age  Gender  family_history  treatment work_interfere care_options  \
# 0      37       1               0          1          Often     Not sure
# 1      44       0               0          0         Rarely           No
# 2      32       0               0          0         Rarely           No
# 3      31       0               1          1          Often          Yes
# 4      31       0               0          0          Never           No
# ...   ...     ...             ...        ...            ...          ...
# 1254   26       0               0          1       Adaptive           No
# 1255   32       0               1          1          Often          Yes
# 1256   34       0               1          1      Sometimes          Yes
# 1257   46       1               0          0       Adaptive          Yes
# 1258   25       0               1          1      Sometimes          Yes
#
#      wellness_program   seek_help mental_health_consequence  \
# 0                  No         Yes                        No
# 1          Don't know  Don't know                     Maybe
# 2                  No          No                        No
# 3                  No          No                       Yes
# 4          Don't know  Don't know                        No
# ...               ...         ...                       ...
# 1254               No          No                        No
# 1255               No          No                        No
# 1256               No          No                       Yes
# 1257               No          No                       Yes
# 1258               No          No                     Maybe
#
#      phys_health_consequence
# 0                         No
# 1                         No
# 2                         No
# 3                        Yes
# 4                         No
# ...                      ...
# 1254                      No
# 1255                      No
# 1256                     Yes
# 1257                      No
# 1258                      No
#
# [1213 rows x 10 columns]

# %%
dataset.work_interfere.value_counts()
# Out:
# work_interfere
# Sometimes    456
# Adaptive     244
# Never        206
# Rarely       167
# Often        140
# Name: count, dtype: int64

# %%
work_map = {'Never': 0, 'Sometimes': 1, 'Rarely': 2, 'Often': 3, 'Adaptive': 4}
dataset['work_interfere'] = dataset['work_interfere'].map(work_map)

# %%
dataset
# Out:
#       Age  Gender  family_history  treatment  work_interfere care_options  \
# 0      37       1               0          1               3     Not sure
# 1      44       0               0          0               2           No
# 2      32       0               0          0               2           No
# 3      31       0               1          1               3          Yes
# 4      31       0               0          0               0           No
# ...   ...     ...             ...        ...             ...          ...
# 1254   26       0               0          1               4           No
# 1255   32       0               1          1               3          Yes
# 1256   34       0               1          1               1          Yes
# 1257   46       1               0          0               4          Yes
# 1258   25       0               1          1               1          Yes
#
#      wellness_program   seek_help mental_health_consequence  \
# 0                  No         Yes                        No
# 1          Don't know  Don't know                     Maybe
# 2                  No          No                        No
# 3                  No          No                       Yes
# 4          Don't know  Don't know                        No
# ...               ...         ...                       ...
# 1254               No          No                        No
# 1255               No          No                        No
# 1256               No          No                       Yes
# 1257               No          No                       Yes
# 1258               No          No                     Maybe
#
#      phys_health_consequence
# 0                         No
# 1                         No
# 2                         No
# 3                        Yes
# 4                         No
# ...                      ...
# 1254                      No
# 1255                      No
# 1256                     Yes
# 1257                      No
# 1258                      No
#
# [1213 rows x 10 columns]

# %%
dataset.care_options.value_counts()
# Out:
# care_options
# No          474
# Yes         435
# Not sure    304
# Name: count, dtype: int64

# %%
care_map = {'No': 0, 'Yes': 1, 'Not sure': 2}
dataset['care_options'] = dataset['care_options'].map(care_map)

# %%
dataset
# Out:
#       Age  Gender  family_history  treatment  work_interfere  care_options  \
# 0      37       1               0          1               3             2
# 1      44       0               0          0               2             0
# 2      32       0               0          0               2             0
# 3      31       0               1          1               3             1
# 4      31       0               0          0               0             0
# ...   ...     ...             ...        ...             ...           ...
# 1254   26       0               0          1               4             0
# 1255   32       0               1          1               3             1
# 1256   34       0               1          1               1             1
# 1257   46       1               0          0               4             1
# 1258   25       0               1          1               1             1
#
#      wellness_program   seek_help mental_health_consequence  \
# 0                  No         Yes                        No
# 1          Don't know  Don't know                     Maybe
# 2                  No          No                        No
# 3                  No          No                       Yes
# 4          Don't know  Don't know                        No
# ...               ...         ...                       ...
# 1254               No          No                        No
# 1255               No          No                        No
# 1256               No          No                       Yes
# 1257               No          No                       Yes
# 1258               No          No                     Maybe
#
#      phys_health_consequence
# 0                         No
# 1                         No
# 2                         No
# 3                        Yes
# 4                         No
# ...                      ...
# 1254                      No
# 1255                      No
# 1256                     Yes
# 1257                      No
# 1258                      No
#
# [1213 rows x 10 columns]

# %%
dataset.wellness_program.value_counts()
# Out:
# wellness_program
# No            806
# Yes           224
# Don't know    183
# Name: count, dtype: int64

# %%
wellness_map = {'No': 0, 'Yes': 1, "Don't know": 2}
dataset['wellness_program'] = dataset['wellness_program'].map(wellness_map)

# %%
dataset
# Out:
#       Age  Gender  family_history  treatment  work_interfere  care_options  \
# 0      37       1               0          1               3             2
# 1      44       0               0          0               2             0
# 2      32       0               0          0               2             0
# 3      31       0               1          1               3             1
# 4      31       0               0          0               0             0
# ...   ...     ...             ...        ...             ...           ...
# 1254   26       0               0          1               4             0
# 1255   32       0               1          1               3             1
# 1256   34       0               1          1               1             1
# 1257   46       1               0          0               4             1
# 1258   25       0               1          1               1             1
#
#       wellness_program   seek_help mental_health_consequence  \
# 0                    0         Yes                        No
# 1                    2  Don't know                     Maybe
# 2                    0          No                        No
# 3                    0          No                       Yes
# 4                    2  Don't know                        No
# ...                ...         ...                       ...
# 1254                 0          No                        No
# 1255                 0          No                        No
# 1256                 0          No                       Yes
# 1257                 0          No                       Yes
# 1258                 0          No                     Maybe
#
#      phys_health_consequence
# 0                         No
# 1                         No
# 2                         No
# 3                        Yes
# 4                         No
# ...                      ...
# 1254                      No
# 1255                      No
# 1256                     Yes
# 1257                      No
# 1258                      No
#
# [1213 rows x 10 columns]

# %%
dataset.seek_help.value_counts()
# Out:
# seek_help
# No            614
# Don't know    355
# Yes           244
# Name: count, dtype: int64

# %%
seek_map = {'No': 0, 'Yes': 1, "Don't know": 2}
dataset['seek_help'] = dataset['seek_help'].map(seek_map)

# %%
dataset
# Out:
#       Age  Gender  family_history  treatment  work_interfere  care_options  \
# 0      37       1               0          1               3             2
# 1      44       0               0          0               2             0
# 2      32       0               0          0               2             0
# 3      31       0               1          1               3             1
# 4      31       0               0          0               0             0
# ...   ...     ...             ...        ...             ...           ...
# 1254   26       0               0          1               4             0
# 1255   32       0               1          1               3             1
# 1256   34       0               1          1               1             1
# 1257   46       1               0          0               4             1
# 1258   25       0               1          1               1             1
#
#       wellness_program  seek_help mental_health_consequence  \
# 0                    0          1                        No
# 1                    2          2                     Maybe
# 2                    0          0                        No
# 3                    0          0                       Yes
# 4                    2          2                        No
# ...                ...        ...                       ...
# 1254                 0          0                        No
# 1255                 0          0                        No
# 1256                 0          0                       Yes
# 1257                 0          0                       Yes
# 1258                 0          0                     Maybe
#
#      phys_health_consequence
# 0                         No
# 1                         No
# 2                         No
# 3                        Yes
# 4                         No
# ...                      ...
# 1254                      No
# 1255                      No
# 1256                     Yes
# 1257                      No
# 1258                      No
#
# [1213 rows x 10 columns]

# %%
dataset.mental_health_consequence.value_counts()
# Out:
# mental_health_consequence
# Maybe    464
# No       461
# Yes      288
# Name: count, dtype: int64

# %%
mental_map = {'No': 0, 'Yes': 1, 'Maybe': 2}
dataset['mental_health_consequence'] = dataset['mental_health_consequence'].map(mental_map)

# %%
dataset
# Out:
#       Age  Gender  family_history  treatment  work_interfere  care_options  \
# 0      37       1               0          1               3             2
# 1      44       0               0          0               2             0
# 2      32       0               0          0               2             0
# 3      31       0               1          1               3             1
# 4      31       0               0          0               0             0
# ...   ...     ...             ...        ...             ...           ...
# 1254   26       0               0          1               4             0
# 1255   32       0               1          1               3             1
# 1256   34       0               1          1               1             1
# 1257   46       1               0          0               4             1
# 1258   25       0               1          1               1             1
#
#       wellness_program  seek_help  mental_health_consequence  \
# 0                    0          1                          0
# 1                    2          2                          2
# 2                    0          0                          0
# 3                    0          0                          1
# 4                    2          2                          0
# ...                ...        ...                        ...
# 1254                 0          0                          0
# 1255                 0          0                          0
# 1256                 0          0                          1
# 1257                 0          0                          1
# 1258                 0          0                          2
#
#      phys_health_consequence
# 0                         No
# 1                         No
# 2                         No
# 3                        Yes
# 4                         No
# ...                      ...
# 1254                      No
# 1255                      No
# 1256                     Yes
# 1257                      No
# 1258                      No
#
# [1213 rows x 10 columns]

# %%
dataset.phys_health_consequence.value_counts()
# Out:
# phys_health_consequence
# No       888
# Maybe    264
# Yes       61
# Name: count, dtype: int64

# %%
phys_map = {'No': 0, 'Yes': 1, 'Maybe': 2}
dataset['phys_health_consequence'] = dataset['phys_health_consequence'].map(mental_map)

# %%
dataset
# Out:
#       Age  Gender  family_history  treatment  work_interfere  care_options  \
# 0      37       1               0          1               3             2
# 1      44       0               0          0               2             0
# 2      32       0               0          0               2             0
# 3      31       0               1          1               3             1
# 4      31       0               0          0               0             0
# ...   ...     ...             ...        ...             ...           ...
# 1254   26       0               0          1               4             0
# 1255   32       0               1          1               3             1
# 1256   34       0               1          1               1             1
# 1257   46       1               0          0               4             1
# 1258   25       0               1          1               1             1
#
#       wellness_program  seek_help  mental_health_consequence  \
# 0                    0          1                          0
# 1                    2          2                          2
# 2                    0          0                          0
# 3                    0          0                          1
# 4                    2          2                          0
# ...                ...        ...                        ...
# 1254                 0          0                          0
# 1255                 0          0                          0
# 1256                 0          0                          1
# 1257                 0          0                          1
# 1258                 0          0                          2
#
#       phys_health_consequence
# 0                           0
# 1                           0
# 2                           0
# 3                           1
# 4                           0
# ...                       ...
# 1254                        0
# 1255                        0
# 1256                        1
# 1257                        0
# 1258                        0
#
# [1213 rows x 10 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_dataset = scaler.fit_transform(dataset)
print(scaled_dataset)
# Out:
# [[ 0.64232951  1.63859152 -0.80922377 ...  0.24601861 -1.14797928
#   -0.58665804]
#  [ 1.56689636 -0.51250319 -0.80922377 ...  1.39822161  1.14231491
#   -0.58665804]
#  [-0.01807539 -0.51250319 -0.80922377 ... -0.90618438 -1.14797928
#   -0.58665804]
#  ...
#  [ 0.24608657 -0.51250319  1.23575213 ... -0.90618438 -0.00283219
#    0.62151888]
#  [ 1.83105832  1.63859152 -0.80922377 ... -0.90618438 -0.00283219
#   -0.58665804]
#  [-0.94264224 -0.51250319  1.23575213 ... -0.90618438  1.14231491
#   -0.58665804]]

# %%
from sklearn.cluster import KMeans
scaled_dataset = pd.DataFrame(scaled_dataset, columns =['Age', 'Gender', 'family_history', 'treatment', 'work_interfere', 'care_options', 'wellness_program', 'seek_help', 'mental_health_consequence', 'phys_health_consequence'])

scaler = StandardScaler()
scaled_features = scaler.fit_transform(scaled_dataset)

kmeans = KMeans(n_clusters=10, random_state=42)
kmeans.fit(scaled_features)

scaled_dataset['Cluster'] = kmeans.labels_

print(scaled_dataset)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#            Age    Gender  family_history  treatment  work_interfere  \
# 0     0.642330  1.638592       -0.809224   0.971550        0.860872
# 1     1.566896 -0.512503       -0.809224  -1.029283        0.142195
# 2    -0.018075 -0.512503       -0.809224  -1.029283        0.142195
# 3    -0.150156 -0.512503        1.235752   0.971550        0.860872
# 4    -0.150156 -0.512503       -0.809224  -1.029283       -1.295159
# ...        ...       ...             ...        ...             ...
# 1208 -0.810561 -0.512503       -0.809224   0.971550        1.579549
# 1209 -0.018075 -0.512503        1.235752   0.971550        0.860872
# 1210  0.246087 -0.512503        1.235752   0.971550       -0.576482
# 1211  1.831058  1.638592       -0.809224  -1.029283        1.579549
# 1212 -0.942642 -0.512503        1.235752   0.971550       -0.576482
#
#       care_options  wellness_program  seek_help  mental_health_consequence  \
# 0         1.445958         -0.654938   0.246019                  -1.147979
# 1        -1.090481          2.038079   1.398222                   1.142315
# 2        -1.090481         -0.654938  -0.906184                  -1.147979
# 3         0.177739         -0.654938  -0.906184                  -0.002832
# 4        -1.090481          2.038079   1.398222                  -1.147979
# ...            ...               ...        ...                        ...
# 1208     -1.090481         -0.654938  -0.906184                  -1.147979
# 1209      0.177739         -0.654938  -0.906184                  -1.147979
# 1210      0.177739         -0.654938  -0.906184                  -0.002832
# 1211      0.177739         -0.654938  -0.906184                  -0.002832
# 1212      0.177739         -0.654938  -0.906184                   1.142315
#
#       phys_health_consequence  Cluster
# 0                   -0.586658        3
# 1                   -0.586658        5
# 2                   -0.586658        6
# 3                    0.621519        2
# 4                   -0.586658        1
# ...                       ...      ...
# 1208                -0.586658        0
# 1209                -0.586658        2
# 1210                 0.621519        2
# 1211                -0.586658        4
# 1212                -0.586658        2
#
# [1213 rows x 11 columns]

# %%
dataset['Cluster'] = scaled_dataset['Cluster'].values

# %%
dataset
# Out:
#       Age  Gender  family_history  treatment  work_interfere  care_options  \
# 0      37       1               0          1               3             2
# 1      44       0               0          0               2             0
# 2      32       0               0          0               2             0
# 3      31       0               1          1               3             1
# 4      31       0               0          0               0             0
# ...   ...     ...             ...        ...             ...           ...
# 1254   26       0               0          1               4             0
# 1255   32       0               1          1               3             1
# 1256   34       0               1          1               1             1
# 1257   46       1               0          0               4             1
# 1258   25       0               1          1               1             1
#
#       wellness_program  seek_help  mental_health_consequence  \
# 0                    0          1                          0
# 1                    2          2                          2
# 2                    0          0                          0
# 3                    0          0                          1
# 4                    2          2                          0
# ...                ...        ...                        ...
# 1254                 0          0                          0
# 1255                 0          0                          0
# 1256                 0          0                          1
# 1257                 0          0                          1
# 1258                 0          0                          2
#
#       phys_health_consequence  Cluster
# 0                           0        3
# 1                           0        5
# 2                           0        6
# 3                           1        2
# 4                           0        1
# ...                       ...      ...
# 1254                        0        0
# 1255                        0        2
# 1256                        1        2
# 1257                        0        4
# 1258                        0        2
#
# [1213 rows x 11 columns]

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
train_dataset
# Out:
#       Age  Gender  family_history  treatment  work_interfere  care_options  \
# 932    43       0               0          1               1             1
# 854    31       0               1          0               4             2
# 55     27       0               1          1               2             1
# 533    23       0               0          0               2             0
# 503    25       0               0          0               0             2
# ...   ...     ...             ...        ...             ...           ...
# 1076   43       0               1          1               1             2
# 326    30       1               0          0               0             1
# 787    25       0               1          1               1             1
# 915    30       0               0          1               1             0
# 567    32       0               0          1               1             0
#
#       wellness_program  seek_help  mental_health_consequence  \
# 932                  0          1                          1
# 854                  0          0                          2
# 55                   0          0                          2
# 533                  0          2                          0
# 503                  2          1                          0
# ...                ...        ...                        ...
# 1076                 0          2                          2
# 326                  1          1                          2
# 787                  2          2                          2
# 915                  0          0                          1
# 567                  0          1                          0
#
#       phys_health_consequence  Cluster
# 932                         2        8
# 854                         0        4
# 55                          0        2
# 533                         0        6
# 503                         0        1
# ...                       ...      ...
# 1076                        2        8
# 326                         2        9
# 787                         0        7
# 915                         2        9
# 567                         0        0
#
# [970 rows x 11 columns]

# %%
test_dataset
# Out:
#       Age  Gender  family_history  treatment  work_interfere  care_options  \
# 11     29       0               0          0               0             2
# 23     41       0               0          1               0             0
# 24     33       0               1          1               2             2
# 25     35       0               1          1               1             1
# 28     34       0               0          1               1             2
# ...   ...     ...             ...        ...             ...           ...
# 1236   60       0               0          1               3             0
# 1239   30       0               0          0               1             0
# 1247   36       0               0          1               3             0
# 1254   26       0               0          1               4             0
# 1255   32       0               1          1               3             1
#
#       wellness_program  seek_help  mental_health_consequence  \
# 11                   0          0                          0
# 23                   0          2                          2
# 24                   2          1                          0
# 25                   0          2                          1
# 28                   0          2                          0
# ...                ...        ...                        ...
# 1236                 1          2                          2
# 1239                 0          0                          2
# 1247                 0          0                          1
# 1254                 0          0                          0
# 1255                 0          0                          0
#
#       phys_health_consequence  Cluster
# 11                          0        6
# 23                          0        0
# 24                          0        7
# 25                          0        7
# 28                          0        0
# ...                       ...      ...
# 1236                        2        8
# 1239                        0        6
# 1247                        0        0
# 1254                        0        0
# 1255                        0        2
#
# [243 rows x 11 columns]

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('Cluster')
test_labels = test_features.pop('Cluster')

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(np.asarray(train_features))
print(normalizer.mean.numpy())
first = np.array(train_features[:1])

with np.printoptions(precision=2, suppress=True):
  print('First example:', first)
  print()
  print('Normalized:', normalizer(first).numpy())
# Out:
# [[32.169067    0.22783503  0.4020618   0.5041237   1.8329895   0.85670096
#    0.49484524  0.7927834   0.9907217   0.46494842]]
# First example: [[43  0  0  1  1  1  0  1  1  2]]
#
# Normalized: [[ 1.44 -0.5  -0.82  0.99 -0.59  0.18 -0.66  0.24  0.01  1.88]]

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(train_features.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_features, train_labels, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 4s 32ms/step - loss: 3.5084 - accuracy: 0.1121 - val_loss: 2.3087 - val_accuracy: 0.1237
# Epoch 2/50
# 25/25 [==============================] - 0s 11ms/step - loss: 2.2645 - accuracy: 0.1727 - val_loss: 2.1648 - val_accuracy: 0.2371
# Epoch 3/50
# 25/25 [==============================] - 0s 19ms/step - loss: 2.1174 - accuracy: 0.2152 - val_loss: 2.0888 - val_accuracy: 0.2268
# Epoch 4/50
# 25/25 [==============================] - 0s 16ms/step - loss: 2.0090 - accuracy: 0.3325 - val_loss: 1.9678 - val_accuracy: 0.3557
# Epoch 5/50
# 25/25 [==============================] - 0s 12ms/step - loss: 1.8782 - accuracy: 0.4343 - val_loss: 1.7905 - val_accuracy: 0.4897
# Epoch 6/50
# 25/25 [==============================] - 1s 25ms/step - loss: 1.7377 - accuracy: 0.5026 - val_loss: 1.7027 - val_accuracy: 0.4588
# Epoch 7/50
# 25/25 [==============================] - 0s 13ms/step - loss: 1.6036 - accuracy: 0.5374 - val_loss: 1.5573 - val_accuracy: 0.5825
# Epoch 8/50
# 25/25 [==============================] - 0s 11ms/step - loss: 1.4734 - accuracy: 0.5593 - val_loss: 1.4361 - val_accuracy: 0.5876
# Epoch 9/50
# 25/25 [==============================] - 0s 12ms/step - loss: 1.3565 - accuracy: 0.6044 - val_loss: 1.3223 - val_accuracy: 0.6031
# Epoch 10/50
# 25/25 [==============================] - 0s 9ms/step - loss: 1.2636 - accuracy: 0.6095 - val_loss: 1.2285 - val_accuracy: 0.6546
# Epoch 11/50
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1961 - accuracy: 0.6263 - val_loss: 1.1117 - val_accuracy: 0.6753
# Epoch 12/50
# 25/25 [==============================] - 0s 13ms/step - loss: 1.0637 - accuracy: 0.6946 - val_loss: 1.0508 - val_accuracy: 0.6804
# Epoch 13/50
# 25/25 [==============================] - 0s 9ms/step - loss: 1.0085 - accuracy: 0.6920 - val_loss: 0.9447 - val_accuracy: 0.7577
# Epoch 14/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.9138 - accuracy: 0.7500 - val_loss: 0.8975 - val_accuracy: 0.7526
# Epoch 15/50
# 25/25 [==============================] - 0s 14ms/step - loss: 0.8523 - accuracy: 0.7655 - val_loss: 0.8429 - val_accuracy: 0.7784
# Epoch 16/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.8096 - accuracy: 0.7758 - val_loss: 0.8074 - val_accuracy: 0.7732
# Epoch 17/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.7527 - accuracy: 0.7758 - val_loss: 0.7605 - val_accuracy: 0.7835
# Epoch 18/50
# 25/25 [==============================] - 0s 5ms/step - loss: 0.7146 - accuracy: 0.7887 - val_loss: 0.6653 - val_accuracy: 0.8299
# Epoch 19/50
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6590 - accuracy: 0.8028 - val_loss: 0.6664 - val_accuracy: 0.8247
# Epoch 20/50
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6234 - accuracy: 0.8209 - val_loss: 0.6247 - val_accuracy: 0.8247
# Epoch 21/50
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6014 - accuracy: 0.8273 - val_loss: 0.6140 - val_accuracy: 0.8144
# Epoch 22/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5669 - accuracy: 0.8428 - val_loss: 0.5602 - val_accuracy: 0.8454
# Epoch 23/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5523 - accuracy: 0.8286 - val_loss: 0.5675 - val_accuracy: 0.8402
# Epoch 24/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5352 - accuracy: 0.8402 - val_loss: 0.5228 - val_accuracy: 0.8660
# Epoch 25/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5016 - accuracy: 0.8505 - val_loss: 0.4611 - val_accuracy: 0.8660
# Epoch 26/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4784 - accuracy: 0.8634 - val_loss: 0.4547 - val_accuracy: 0.8711
# Epoch 27/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4524 - accuracy: 0.8647 - val_loss: 0.4456 - val_accuracy: 0.8814
# Epoch 28/50
# 25/25 [==============================] - 0s 5ms/step - loss: 0.4455 - accuracy: 0.8711 - val_loss: 0.4288 - val_accuracy: 0.8763
# Epoch 29/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4244 - accuracy: 0.8698 - val_loss: 0.4410 - val_accuracy: 0.8763
# Epoch 30/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4254 - accuracy: 0.8814 - val_loss: 0.4578 - val_accuracy: 0.8763
# Epoch 31/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4212 - accuracy: 0.8570 - val_loss: 0.4156 - val_accuracy: 0.8918
# Epoch 32/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4109 - accuracy: 0.8698 - val_loss: 0.4172 - val_accuracy: 0.8763
# Epoch 33/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3765 - accuracy: 0.8853 - val_loss: 0.3851 - val_accuracy: 0.8918
# Epoch 34/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3684 - accuracy: 0.8892 - val_loss: 0.3651 - val_accuracy: 0.8814
# Epoch 35/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3482 - accuracy: 0.9021 - val_loss: 0.3974 - val_accuracy: 0.8711
# Epoch 36/50
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3457 - accuracy: 0.9021 - val_loss: 0.3809 - val_accuracy: 0.8814
# Epoch 37/50
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3401 - accuracy: 0.9046 - val_loss: 0.3501 - val_accuracy: 0.9124
# Epoch 38/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3236 - accuracy: 0.9149 - val_loss: 0.3519 - val_accuracy: 0.8866
# Epoch 39/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3264 - accuracy: 0.9085 - val_loss: 0.3238 - val_accuracy: 0.8969
# Epoch 40/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3348 - accuracy: 0.8995 - val_loss: 0.3273 - val_accuracy: 0.8969
# Epoch 41/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3049 - accuracy: 0.9046 - val_loss: 0.3316 - val_accuracy: 0.8918
# Epoch 42/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2907 - accuracy: 0.9149 - val_loss: 0.3143 - val_accuracy: 0.9021
# Epoch 43/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2965 - accuracy: 0.9201 - val_loss: 0.2904 - val_accuracy: 0.9124
# Epoch 44/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2914 - accuracy: 0.9188 - val_loss: 0.2844 - val_accuracy: 0.9072
# Epoch 45/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2778 - accuracy: 0.9214 - val_loss: 0.3006 - val_accuracy: 0.9278
# Epoch 46/50
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2764 - accuracy: 0.9124 - val_loss: 0.2989 - val_accuracy: 0.9175
# Epoch 47/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.2840 - accuracy: 0.9149 - val_loss: 0.2933 - val_accuracy: 0.8866
# Epoch 48/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2756 - accuracy: 0.9124 - val_loss: 0.3085 - val_accuracy: 0.9175
# Epoch 49/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2457 - accuracy: 0.9265 - val_loss: 0.3292 - val_accuracy: 0.8969
# Epoch 50/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2600 - accuracy: 0.9188 - val_loss: 0.2938 - val_accuracy: 0.9021

# %%
loss, accuracy = model.evaluate(test_features, test_labels)
print(f"Test Accuracy: {accuracy}")
# Out:
# 8/8 [==============================] - 0s 12ms/step - loss: 0.3024 - accuracy: 0.8971
# Test Accuracy: 0.8971193432807922

# %%
LABEL = ["ayam", "bebek", "cicak", "domba", "elang", "flamingo", "gajah", "harimau", "ikan", "jerapah"]
new_data = [[49,  0,  1,  0,  4,  2,  0,  1,  1,  2]]

prediksi = model.predict(new_data)
predicted_classes = np.argmax(prediksi, axis=1)
predicted_classes = LABEL[predicted_classes[0]]
print(predicted_classes)
print(prediksi)
# Out:
# 1/1 [==============================] - 0s 194ms/step
# ikan
# [[6.4067065e-04 3.5990240e-06 2.0905407e-03 2.9118839e-04 1.0316965e-01
#   4.1584604e-04 5.3912384e-04 6.7965424e-04 8.2802355e-01 6.4146131e-02]]

# %%
import pickle

# %%
with open("model_klasifikasi.pkl", "wb") as model_file:
  pickle.dump(model, model_file)
