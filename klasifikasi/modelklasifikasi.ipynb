# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('dataset_mental3.csv')

# %%
dataset
# Out:
#       Unnamed: 0  Age  Gender  family_history  treatment  work_interfere  \
# 0              0   37       1               0          1               3
# 1              1   44       0               0          0               2
# 2              2   32       0               0          0               2
# 3              3   31       0               1          1               3
# 4              4   31       0               0          0               0
# ...          ...  ...     ...             ...        ...             ...
# 1208        1208   26       0               0          1               4
# 1209        1209   32       0               1          1               3
# 1210        1210   34       0               1          1               1
# 1211        1211   46       1               0          0               4
# 1212        1212   25       0               1          1               1
#
#       care_options  wellness_program  seek_help  mental_health_consequence  \
# 0                2                 0          1                          0
# 1                0                 2          2                          2
# 2                0                 0          0                          0
# 3                1                 0          0                          1
# 4                0                 2          2                          0
# ...            ...               ...        ...                        ...
# 1208             0                 0          0                          0
# 1209             1                 0          0                          0
# 1210             1                 0          0                          1
# 1211             1                 0          0                          1
# 1212             1                 0          0                          2
#
#       phys_health_consequence  Cluster
# 0                           0        3
# 1                           0        5
# 2                           0        6
# 3                           1        2
# 4                           0        1
# ...                       ...      ...
# 1208                        0        0
# 1209                        0        2
# 1210                        1        2
# 1211                        0        4
# 1212                        0        2
#
# [1213 rows x 12 columns]

# %%
dataset = dataset.drop('Unnamed: 0', axis = True)

# %%
dataset
# Out:
#       Age  Gender  family_history  treatment  work_interfere  care_options  \
# 0      37       1               0          1               3             2
# 1      44       0               0          0               2             0
# 2      32       0               0          0               2             0
# 3      31       0               1          1               3             1
# 4      31       0               0          0               0             0
# ...   ...     ...             ...        ...             ...           ...
# 1208   26       0               0          1               4             0
# 1209   32       0               1          1               3             1
# 1210   34       0               1          1               1             1
# 1211   46       1               0          0               4             1
# 1212   25       0               1          1               1             1
#
#       wellness_program  seek_help  mental_health_consequence  \
# 0                    0          1                          0
# 1                    2          2                          2
# 2                    0          0                          0
# 3                    0          0                          1
# 4                    2          2                          0
# ...                ...        ...                        ...
# 1208                 0          0                          0
# 1209                 0          0                          0
# 1210                 0          0                          1
# 1211                 0          0                          1
# 1212                 0          0                          2
#
#       phys_health_consequence  Cluster
# 0                           0        3
# 1                           0        5
# 2                           0        6
# 3                           1        2
# 4                           0        1
# ...                       ...      ...
# 1208                        0        0
# 1209                        0        2
# 1210                        1        2
# 1211                        0        4
# 1212                        0        2
#
# [1213 rows x 11 columns]

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
print(train_dataset)
# Out:
#       Age  Gender  family_history  treatment  work_interfere  care_options  \
# 899    43       0               0          1               1             1
# 830    31       0               1          0               4             2
# 55     27       0               1          1               2             1
# 523    23       0               0          0               2             0
# 495    25       0               0          0               0             2
# ...   ...     ...             ...        ...             ...           ...
# 1038   43       0               1          1               1             2
# 322    30       1               0          0               0             1
# 765    25       0               1          1               1             1
# 885    30       0               0          1               1             0
# 556    32       0               0          1               1             0
#
#       wellness_program  seek_help  mental_health_consequence  \
# 899                  0          1                          1
# 830                  0          0                          2
# 55                   0          0                          2
# 523                  0          2                          0
# 495                  2          1                          0
# ...                ...        ...                        ...
# 1038                 0          2                          2
# 322                  1          1                          2
# 765                  2          2                          2
# 885                  0          0                          1
# 556                  0          1                          0
#
#       phys_health_consequence  Cluster
# 899                         2        8
# 830                         0        4
# 55                          0        2
# 523                         0        6
# 495                         0        1
# ...                       ...      ...
# 1038                        2        8
# 322                         2        9
# 765                         0        7
# 885                         2        9
# 556                         0        0
#
# [970 rows x 11 columns]

# %%
print(test_dataset)
# Out:
#       Age  Gender  family_history  treatment  work_interfere  care_options  \
# 11     29       0               0          0               0             2
# 23     41       0               0          1               0             0
# 24     33       0               1          1               2             2
# 25     35       0               1          1               1             1
# 28     34       0               0          1               1             2
# ...   ...     ...             ...        ...             ...           ...
# 1194   60       0               0          1               3             0
# 1197   30       0               0          0               1             0
# 1202   36       0               0          1               3             0
# 1208   26       0               0          1               4             0
# 1209   32       0               1          1               3             1
#
#       wellness_program  seek_help  mental_health_consequence  \
# 11                   0          0                          0
# 23                   0          2                          2
# 24                   2          1                          0
# 25                   0          2                          1
# 28                   0          2                          0
# ...                ...        ...                        ...
# 1194                 1          2                          2
# 1197                 0          0                          2
# 1202                 0          0                          1
# 1208                 0          0                          0
# 1209                 0          0                          0
#
#       phys_health_consequence  Cluster
# 11                          0        6
# 23                          0        0
# 24                          0        7
# 25                          0        7
# 28                          0        0
# ...                       ...      ...
# 1194                        2        8
# 1197                        0        6
# 1202                        0        0
# 1208                        0        0
# 1209                        0        2
#
# [243 rows x 11 columns]

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('Cluster')
test_labels = test_features.pop('Cluster')

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(np.asarray(train_features))
print(normalizer.mean.numpy())
first = np.array(train_features[:1])

with np.printoptions(precision=2, suppress=True):
  print('First example:', first)
  print()
  print('Normalized:', normalizer(first).numpy())
# Out:
# [[32.169067    0.22783503  0.4020618   0.5041237   1.8329895   0.85670096
#    0.49484524  0.7927834   0.9907217   0.46494842]]
# First example: [[43  0  0  1  1  1  0  1  1  2]]
#
# Normalized: [[ 1.44 -0.5  -0.82  0.99 -0.59  0.18 -0.66  0.24  0.01  1.88]]

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(train_features.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_features, train_labels, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 2s 19ms/step - loss: 3.3326 - accuracy: 0.1018 - val_loss: 2.2928 - val_accuracy: 0.1134
# Epoch 2/50
# 25/25 [==============================] - 0s 7ms/step - loss: 2.2162 - accuracy: 0.1765 - val_loss: 2.1057 - val_accuracy: 0.3093
# Epoch 3/50
# 25/25 [==============================] - 0s 7ms/step - loss: 2.0850 - accuracy: 0.2835 - val_loss: 1.9644 - val_accuracy: 0.3866
# Epoch 4/50
# 25/25 [==============================] - 0s 6ms/step - loss: 1.9273 - accuracy: 0.4162 - val_loss: 1.8279 - val_accuracy: 0.4794
# Epoch 5/50
# 25/25 [==============================] - 0s 4ms/step - loss: 1.7829 - accuracy: 0.4871 - val_loss: 1.6479 - val_accuracy: 0.5515
# Epoch 6/50
# 25/25 [==============================] - 0s 6ms/step - loss: 1.6314 - accuracy: 0.5490 - val_loss: 1.5131 - val_accuracy: 0.6237
# Epoch 7/50
# 25/25 [==============================] - 0s 6ms/step - loss: 1.4909 - accuracy: 0.5915 - val_loss: 1.3722 - val_accuracy: 0.6753
# Epoch 8/50
# 25/25 [==============================] - 0s 9ms/step - loss: 1.3517 - accuracy: 0.6637 - val_loss: 1.2576 - val_accuracy: 0.7216
# Epoch 9/50
# 25/25 [==============================] - 0s 10ms/step - loss: 1.2307 - accuracy: 0.6946 - val_loss: 1.1713 - val_accuracy: 0.7526
# Epoch 10/50
# 25/25 [==============================] - 0s 5ms/step - loss: 1.1170 - accuracy: 0.7448 - val_loss: 1.0761 - val_accuracy: 0.7526
# Epoch 11/50
# 25/25 [==============================] - 0s 9ms/step - loss: 1.0229 - accuracy: 0.7590 - val_loss: 0.9988 - val_accuracy: 0.7526
# Epoch 12/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.9554 - accuracy: 0.7436 - val_loss: 0.8954 - val_accuracy: 0.8041
# Epoch 13/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.8758 - accuracy: 0.7745 - val_loss: 0.8217 - val_accuracy: 0.7990
# Epoch 14/50
# 25/25 [==============================] - 0s 5ms/step - loss: 0.7970 - accuracy: 0.8131 - val_loss: 0.7511 - val_accuracy: 0.8402
# Epoch 15/50
# 25/25 [==============================] - 0s 5ms/step - loss: 0.7544 - accuracy: 0.8067 - val_loss: 0.7314 - val_accuracy: 0.8247
# Epoch 16/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.7025 - accuracy: 0.8247 - val_loss: 0.6959 - val_accuracy: 0.7732
# Epoch 17/50
# 25/25 [==============================] - 0s 12ms/step - loss: 0.6663 - accuracy: 0.8144 - val_loss: 0.6680 - val_accuracy: 0.8454
# Epoch 18/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.6213 - accuracy: 0.8608 - val_loss: 0.6001 - val_accuracy: 0.8454
# Epoch 19/50
# 25/25 [==============================] - 0s 12ms/step - loss: 0.5850 - accuracy: 0.8518 - val_loss: 0.6037 - val_accuracy: 0.8505
# Epoch 20/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.5470 - accuracy: 0.8557 - val_loss: 0.5485 - val_accuracy: 0.8711
# Epoch 21/50
# 25/25 [==============================] - 0s 15ms/step - loss: 0.5248 - accuracy: 0.8686 - val_loss: 0.5102 - val_accuracy: 0.8711
# Epoch 22/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.5011 - accuracy: 0.8763 - val_loss: 0.5176 - val_accuracy: 0.8711
# Epoch 23/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4756 - accuracy: 0.8789 - val_loss: 0.4935 - val_accuracy: 0.8814
# Epoch 24/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4569 - accuracy: 0.8879 - val_loss: 0.4363 - val_accuracy: 0.8814
# Epoch 25/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4326 - accuracy: 0.8956 - val_loss: 0.4331 - val_accuracy: 0.8763
# Epoch 26/50
# 25/25 [==============================] - 0s 13ms/step - loss: 0.4068 - accuracy: 0.8930 - val_loss: 0.4077 - val_accuracy: 0.8866
# Epoch 27/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.3933 - accuracy: 0.8982 - val_loss: 0.4030 - val_accuracy: 0.8866
# Epoch 28/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.3786 - accuracy: 0.9008 - val_loss: 0.4123 - val_accuracy: 0.8918
# Epoch 29/50
# 25/25 [==============================] - 0s 13ms/step - loss: 0.3737 - accuracy: 0.8930 - val_loss: 0.3714 - val_accuracy: 0.8866
# Epoch 30/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.3640 - accuracy: 0.9008 - val_loss: 0.3537 - val_accuracy: 0.9124
# Epoch 31/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.3486 - accuracy: 0.9072 - val_loss: 0.3646 - val_accuracy: 0.8969
# Epoch 32/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3553 - accuracy: 0.9008 - val_loss: 0.3847 - val_accuracy: 0.8866
# Epoch 33/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.3295 - accuracy: 0.9034 - val_loss: 0.3677 - val_accuracy: 0.8969
# Epoch 34/50
# 25/25 [==============================] - 0s 12ms/step - loss: 0.3290 - accuracy: 0.8995 - val_loss: 0.3509 - val_accuracy: 0.8969
# Epoch 35/50
# 25/25 [==============================] - 0s 15ms/step - loss: 0.3281 - accuracy: 0.9034 - val_loss: 0.3659 - val_accuracy: 0.8814
# Epoch 36/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3204 - accuracy: 0.9034 - val_loss: 0.3226 - val_accuracy: 0.9072
# Epoch 37/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.2958 - accuracy: 0.9085 - val_loss: 0.3226 - val_accuracy: 0.9072
# Epoch 38/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.2987 - accuracy: 0.9149 - val_loss: 0.3129 - val_accuracy: 0.9021
# Epoch 39/50
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2914 - accuracy: 0.9124 - val_loss: 0.3274 - val_accuracy: 0.8866
# Epoch 40/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.2873 - accuracy: 0.9137 - val_loss: 0.3369 - val_accuracy: 0.8969
# Epoch 41/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.2699 - accuracy: 0.9188 - val_loss: 0.2853 - val_accuracy: 0.9124
# Epoch 42/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.2740 - accuracy: 0.9111 - val_loss: 0.2951 - val_accuracy: 0.8969
# Epoch 43/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2801 - accuracy: 0.9111 - val_loss: 0.2906 - val_accuracy: 0.9021
# Epoch 44/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2850 - accuracy: 0.9085 - val_loss: 0.2982 - val_accuracy: 0.9072
# Epoch 45/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2601 - accuracy: 0.9162 - val_loss: 0.3293 - val_accuracy: 0.9175
# Epoch 46/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2610 - accuracy: 0.9124 - val_loss: 0.2824 - val_accuracy: 0.9021
# Epoch 47/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2452 - accuracy: 0.9227 - val_loss: 0.2683 - val_accuracy: 0.9072
# Epoch 48/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2474 - accuracy: 0.9162 - val_loss: 0.3022 - val_accuracy: 0.9021
# Epoch 49/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2428 - accuracy: 0.9265 - val_loss: 0.2832 - val_accuracy: 0.9175
# Epoch 50/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2405 - accuracy: 0.9253 - val_loss: 0.2537 - val_accuracy: 0.9124

# %%
loss, accuracy = model.evaluate(train_features, train_labels)
print(f"Test Accuracy: {accuracy}")
# Out:
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2272 - accuracy: 0.9278
# Test Accuracy: 0.9278350472450256

# %%
prediksi = model.predict([[49,  0,  1,  0,  4,  2,  0,  1,  1,  2],[19,  1,  1,  0,  3,  2,  0,  0,  1,  2]])
predicted_classes = np.argmax(prediksi, axis=1)
print(predicted_classes)
print(prediksi)
# Out:
# 1/1 [==============================] - 0s 36ms/step
# [4 9]
# [[1.14492627e-06 8.96145082e-07 4.36532032e-03 1.29220381e-04
#   3.80228430e-01 2.50285491e-03 4.18694224e-03 1.44456606e-03
#   3.08612108e-01 2.98528552e-01]
#  [1.33271601e-06 2.38429311e-05 1.29673805e-03 1.23221345e-01
#   1.83659536e-03 4.55908186e-04 3.13178425e-05 1.98907888e-04
#   1.31345280e-02 8.59799385e-01]]
